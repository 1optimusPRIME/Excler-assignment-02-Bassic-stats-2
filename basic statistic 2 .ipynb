# %% [markdown]
# ### set 1

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
X=pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
X
# Out:
# 0     24.23
# 1     25.53
# 2     25.41
# 3     24.14
# 4     29.62
# 5     28.25
# 6     25.81
# 7     24.39
# 8     40.26
# 9     32.95
# 10    91.36
# 11    25.99
# 12    39.42
# 13    26.71
# 14    35.00
# dtype: float64

# %%
name=['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers','Marriott','MCI',
      'Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways','Warner-Lambert']

# %%
name
# Out:
# ['Allied Signal',
#  'Bankers Trust',
#  'General Mills',
#  'ITT Industries',
#  'J.P.Morgan & Co.',
#  'Lehman Brothers',
#  'Marriott',
#  'MCI',
#  'Merrill Lynch',
#  'Microsoft',
#  'Morgan Stanley',
#  'Sun Microsystems',
#  'Travelers',
#  'US Airways',
#  'Warner-Lambert']

# %%
plt.pie(X,labels=name,autopct='%0.1f%%',shadow=True)
plt.figure(figsize=(8,8))

# %%
sns.boxplot(data=X,color='teal')
# Out:
# <AxesSubplot:>

# %%
# mean 
X.mean()
# Out:
# 33.27133333333333

# %%
# standared deviation 
X.std()
# Out:
# 16.945400921222028

# %%
# variance
X.var()
# Out:
# 287.1466123809524

# %% [markdown]
# ### set 2 (Q.4)

# %%
from scipy import stats
from scipy.stats import norm

# %%
stats.norm.interval(0.99,100,20)
# Out:
# (48.48341392902199, 151.516586070978)

# %% [markdown]
# ### set 4 (Q3)

# %% [markdown]
# n=100, Pop Mean=50, Pop SD=40 As no. of samples is more than 30, we can consider it normal distribution

# %%
# For No investigation P(45
# For Investigation 1-P(45

# %%
# find z-scores at x=45
zscor=(45-50)/(40/100**0.5)
zscor
# Out:
# -1.25

# %%
# find z-scores at x=55
z=(55-50)/(40/100**0.5)
z
# Out:
# 1.25

# %%
# For No investigation P(45
stats.norm.cdf(1.25)-stats.norm.cdf(-1.25)
# Out:
# 0.7887004526662893

# %%
stats.norm.interval(0.7887,loc=50,scale=40/(100**0.5))
# Out:
# (45.00000495667348, 54.99999504332652)

# %%
# For Investigation 1-P(45
1-0.7887
# Out:
# 0.21130000000000004

# %% [markdown]
# ### Answer is D. 21.1%
